# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 99, Loss: 1.772
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 100, Loss: 1.771
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 101, Loss: 1.770
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 102, Loss: 1.769
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 103, Loss: 1.768
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 104, Loss: 1.773
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 105, Loss: 1.768
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 106, Loss: 1.766
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 107, Loss: 1.766
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 108, Loss: 1.766
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 109, Loss: 1.762
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 110, Loss: 1.760
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 111, Loss: 1.762
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 112, Loss: 1.764
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 113, Loss: 1.757
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 114, Loss: 1.755
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 115, Loss: 1.755
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 116, Loss: 1.756
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 117, Loss: 1.755
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 118, Loss: 1.758
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 119, Loss: 1.752
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 120, Loss: 1.751
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 121, Loss: 1.750
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 122, Loss: 1.751
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 123, Loss: 1.748
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 124, Loss: 1.746
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 125, Loss: 1.745
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 126, Loss: 1.749
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 127, Loss: 1.744
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 128, Loss: 1.745
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 129, Loss: 1.745
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 130, Loss: 1.742
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 131, Loss: 1.740
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 132, Loss: 1.743
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 133, Loss: 1.740
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 134, Loss: 1.741
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 135, Loss: 1.738
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 136, Loss: 1.738
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 137, Loss: 1.735
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 138, Loss: 1.736
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 139, Loss: 1.736
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 140, Loss: 1.733
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 141, Loss: 1.735
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 142, Loss: 1.733
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 143, Loss: 1.732
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 144, Loss: 1.730
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 145, Loss: 1.732
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 146, Loss: 1.727
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 147, Loss: 1.728
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 148, Loss: 1.731
# 42606/42606: [===============================>] - ETA 0.1ss
# Pretraining Autoencoder... Epoch: 149, Loss: 1.725

# %%
classvdd.train()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-b71072500a05> in <module>()
# ----> 1 classvdd.train()
#
# ~/Class-outlier/classvdd/train.py in train(self)
#      49         """Training the ClasSVDD model"""
#      50         if self.args.pretrain==True:
# ---> 51             self.load_pretrained_weights()
#      52         else:
#      53             self.net.apply(weights_init_normal)
#
# ~/Class-outlier/classvdd/train.py in load_pretrained_weights(self)
#     110         self.net = network().to(self.device)
#     111         state_dict = torch.load('classvdd/weights/pretrained_parameters_{}.pth'.format(self.args.anormal_class))
# --> 112         self.net.load_state_dict(state_dict['model'], strict=False)
#     113         self.c = self.set_c().to(self.device)
#     114
#
# KeyError: 'model'

# %%
state_dict = torch.load('classvdd/weights/model_parameters_5.pth')
classvdd.net.load_state_dict(state_dict['model'])
classvdd.c = torch.Tensor(state_dict['center']).to(device)

# %%
import torch

from sklearn.metrics import roc_auc_score

def eval(net, c, dataloader, device):
    """Testing the Deep SVDD model"""

    scores = []
    labels1 = []
    labels2 = []
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y1, y2 in dataloader:
            x = x.float().to(device)
            y2 = y2.long().to(device)
            
            z = net(x)
            score = torch.min(torch.sum((z.unsqueeze(1) - c) ** 2, dim=2),dim=1)[0]
            
            scores.append(score.detach().cpu())
            labels1.append(y1.cpu())
            labels2.append(y2.cpu())
    labels1, labels2, scores = torch.cat(labels1).numpy(), torch.cat(labels2).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.3f}'.format(roc_auc_score(labels2, scores)))
    return labels1, labels2, scores

# %%
labels1, labels2, scores = eval(classvdd.net, classvdd.c, dataloader_test, device)

# %%
scores_in = scores[labels2==0]
scores_out = scores[labels2==1]

# %%
plt.hist(scores_in, bins=100, color='b', alpha=0.3, density=True, label='Inlier')
plt.hist(scores_out, bins=100, color='r', alpha=0.3, density=True, label='Outlier')
plt.legend()
